# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
import os

# configure the GPU
physical_devices = tf.config.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
# Out:
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
square_dims = 128
latent_size = int(square_dims/8)
latent_dim = 128

# %%
generator = keras.models.load_model("./production_models/DCGAN")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
generator.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 32768)             4227072
#
#  reshape (Reshape)           (None, 16, 16, 128)       0
#
#  conv2d_transpose (Conv2DTra  (None, 32, 32, 128)      262272
#  nspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 64, 64, 256)      524544
#  ranspose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 256)       0
#
#  conv2d_transpose_2 (Conv2DT  (None, 128, 128, 512)    2097664
#  ranspose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 128, 128, 512)     0
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 3)       38403
#
# =================================================================
# Total params: 7,149,955
# Trainable params: 7,149,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_examples = 5
latent_dim = 128
random_vector = tf.random.normal(shape=(num_examples, latent_dim))
output = generator(random_vector)
f = plt.figure(figsize=(20, 20))
for i in range(num_examples):
    plt.subplot(1, num_examples, i+1)
    plt.imshow(output[i])

plt.show()

# %%
from generator_models import *
# Out:
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\vedan\AppData\Local\Programs\Python\Python38\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
srgan = SRGAN("./models/SRGAN/gen/generator-320")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
srgan.upscale_64_256("./images/real_small.jpeg")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18172/3809483101.py in <module>
# ----> 1 srgan.upscale_64_256("./images/real_small.jpeg")
#
# d:\ML stuff\Gen_ML_sem_4\generator_models.py in upscale_64_256(self, image_path)
#     151         image = load_image(image_path, shape=None)
#     152         image = self.downscale(image, (self.lr_dim, self.lr_dim))
# --> 153         image, dim_ratio, axis = self.pack(image[0])
#     154         image = np.expand_dims(image, axis=0)
#     155
#
# d:\ML stuff\Gen_ML_sem_4\generator_models.py in pack(self, img)
#     123         # resize image to lower_dim, lower_dim
#     124         img = img * 255
# --> 125         img = img.astype(np.uint8)
#     126         img = Image.fromarray(img)
#     127         img = img.resize((int(lower_dim), int(lower_dim)))
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\framework\ops.py in __getattr__(self, name)
#     435                 "tolist", "data"}:
#     436       # TODO(wangpeng): Export the enable_numpy_behavior knob
# --> 437       raise AttributeError("""
#     438         '{}' object has no attribute '{}'.
#     439         If you are looking for numpy-related methods, please run the following:
#
# AttributeError:
#         'EagerTensor' object has no attribute 'astype'.
#         If you are looking for numpy-related methods, please run the following:
#         from tensorflow.python.ops.numpy_ops import np_config
#         np_config.enable_numpy_behavior()
